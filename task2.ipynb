# %% [markdown]
# Type conversion of variable using built-in function

# %%
#1
stn="35"
n=int(stn)
print(type(n),n)
st="4.3"
fn=float(st)
print(type(fn),fn)
# Out:
# <class 'int'> 35
# <class 'float'> 4.3

# %%
#2
x=int(input("enter first number"))
y=int(input("enter second number"))
if x>y:
    print(x," is greater")
elif x<y:
    print(y," is greater")

else:
    print("both are equal")
# Out:
# 4  is greater

# %%
#3
c = float(input("Enter Celsius: "))
f = (c * 9/5)+32
print("Fahrenheit:", f)
# Out:
# Fahrenheit: 113.53999999999999

# %%
#4
word=input("enter word")
ch=input("enter a char")
print( ch in word)
# Out:
# True

# %%
#5 identity:same memory location?
l=[4,2,6]
s=l
r=[3,5]
print(s is l)
print(r is l)
# Out:
# True
# False

# %%
age =2
print(age > 18 and age < 30)
# Out:
# False
